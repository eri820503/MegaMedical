# %%
import megamedical
import megamedical.src.proc_funcs as pf
import megamedical.utils as utils

# %%
# processing bulwark. datasets can either be a string, or a list
# of datasets. If datasets is a list, then you can't visualize.
# if slurm == true, then no visualization is allowed.
pf.process_dataset(datasets=["ACDC"],
                   version='megamedical_v4.0',
                   save_slices=False,
                   slurm=False,
                   visualize=True,
                   redo_processed=True)
# Out:
# Starting: /home/vib9/src/MegaMedical/megamedical/datasets/ACDC/processed/megamedical_v4.0/Challenge2017
# Processing: Challenge2017:   0%|                                                                                                                                                                                                 | 0/100 [00:00<?, ?image/s]
# Processing: Challenge2017:   1%|█▊                                                                                                                                                                                       | 1/100 [00:20<34:30, 20.91s/image]
# Processing: Challenge2017:   2%|███▋                                                                                                                                                                                     | 2/100 [00:35<27:50, 17.04s/image]
# Processing: Challenge2017:   3%|█████▌                                                                                                                                                                                   | 3/100 [00:56<30:41, 18.99s/image]
# Processing: Challenge2017:   4%|███████▍                                                                                                                                                                                 | 4/100 [01:10<27:27, 17.16s/image]
# Processing: Challenge2017:   5%|█████████▎                                                                                                                                                                               | 5/100 [01:28<28:02, 17.71s/image]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [2], in <cell line: 4>()
#       1 # processing bulwark. datasets can either be a string, or a list
#       2 # of datasets. If datasets is a list, then you can't visualize.
#       3 # if slurm == true, then no visualization is allowed.
# ----> 4 pf.process_dataset(datasets=["ACDC"],
#       5                    version='megamedical_v4.0',
#       6                    save_slices=False,
#       7                    slurm=False,
#       8                    visualize=True,
#       9                    redo_processed=True)
#
# File ~/src/MegaMedical/megamedical/src/proc_funcs.py:187, in process_dataset(datasets, version, save_slices, slurm, timeout, visualize, show_hists, redo_processed)
#     185 else:
#     186     dataset_object = dataset_objects[0]
# --> 187     show_processing(dataset_object,
#     188                     subdset="all",
#     189                     version=version,
#     190                     show_hists=show_hists)
#
# File ~/src/MegaMedical/megamedical/src/proc_funcs.py:18, in show_processing(dataset_object, subdset, version, show_hists)
#      16     dset_names = [subdset]
#      17 for dataset in dset_names:
# ---> 18     dataset_object.proc_func(dataset,
#      19                              version=version,
#      20                              show_hists=show_hists,
#      21                              show_imgs=True,
#      22                              save_slices=False,
#      23                              redo_processed=True)
#
# File ~/src/MegaMedical/megamedical/datasets/ACDC/process_assets/process.py:62, in ACDC.proc_func(self, dset_name, version, show_hists, show_imgs, save_slices, redo_processed)
#      56         assert not (loaded_image is None), "Invalid Image"
#      57         assert not (loaded_label is None), "Invalid Label"
#      59         pps.produce_slices(proc_dir,
#      60                           dset_name,
#      61                           loaded_image,
# ---> 62                           loaded_label,
#      63                           self.dset_info[dset_name],
#      64                           show_hists=show_hists,
#      65                           show_imgs=show_imgs)
#      66 except Exception as e:
#      67     print(e)
#
# File ~/src/MegaMedical/megamedical/src/preprocess_scripts.py:83, in produce_slices(root_dir, dataset, loaded_image, loaded_label, dset_info, save_slices, show_hists, show_imgs, subject_name)
#      80         os.makedirs(save_dir)
#      82 #make the volume a 3D cube
# ---> 83 square_modality_image = squarify(normalized_modality_image)
#      84 square_modality_label = squarify(loaded_label)
#      86 #original square image size
#
# File ~/src/MegaMedical/megamedical/utils/proc_utils.py:74, in squarify(M)
#      70         b_right_pad = math.ceil(b_dif/2)
#      72         padding=((a_left_pad,a_right_pad),(b_left_pad,b_right_pad),(0,0))
# ---> 74     return np.pad(M,padding,mode='constant',constant_values=0)
#      75 else:
#      76     raise ValueError("Improper shape for padding.")
#
# File <__array_function__ internals>:5, in pad(*args, **kwargs)
#
# File ~/anaconda3/envs/UVS/lib/python3.9/site-packages/numpy/lib/arraypad.py:803, in pad(array, pad_width, mode, **kwargs)
#     801     for axis, width_pair, value_pair in zip(axes, pad_width, values):
#     802         roi = _view_roi(padded, original_area_slice, axis)
# --> 803         _set_pad_area(roi, axis, width_pair, value_pair)
#     805 elif mode == "empty":
#     806     pass  # Do nothing as _pad_simple already returned the correct result
#
# File ~/anaconda3/envs/UVS/lib/python3.9/site-packages/numpy/lib/arraypad.py:147, in _set_pad_area(padded, axis, width_pair, value_pair)
#     130 """
#     131 Set empty-padded area in given dimension.
#     132
#    (...)
#     144     broadcastable to the shape of `arr`.
#     145 """
#     146 left_slice = _slice_at_axis(slice(None, width_pair[0]), axis)
# --> 147 padded[left_slice] = value_pair[0]
#     149 right_slice = _slice_at_axis(
#     150     slice(padded.shape[axis] - width_pair[1], None), axis)
#     151 padded[right_slice] = value_pair[1]
#
# KeyboardInterrupt:
