# %%
import megamedical
import megamedical.src.proc_funcs as pf
import megamedical.utils as utils

# %%
# processing bulwark. datasets can either be a string, or a list
# of datasets. If datasets is a list, then you can't visualize.
# if slurm == true, then no visualization is allowed.
pf.process_dataset(datasets=["ACDC"],
                   version='4.0',
                   save_slices=True,
                   slurm=False,
                   visualize=False,
                   redo_processed=True,
                   subsets=["megamedical"])
# Out:
# Processing: Challenge2017:   0%|                                                                                                                                                                                                                   | 0/100 [00:00<?, ?image/s]
# Processing: Challenge2017:   1%|██                                                                                                                                                                                                         | 1/100 [00:23<38:27, 23.31s/image]
# Processing: Challenge2017:   2%|████                                                                                                                                                                                                       | 2/100 [00:40<32:29, 19.90s/image]
# Processing: Challenge2017:   3%|██████                                                                                                                                                                                                     | 3/100 [01:04<34:52, 21.57s/image]
# Processing: Challenge2017:   4%|████████                                                                                                                                                                                                   | 4/100 [01:21<31:55, 19.96s/image]
# Processing: Challenge2017:   5%|██████████▏                                                                                                                                                                                                | 5/100 [01:39<30:32, 19.29s/image]
