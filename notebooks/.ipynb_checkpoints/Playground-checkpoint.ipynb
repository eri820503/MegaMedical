# %%
import megamedical
import megamedical.src.proc_funcs as pf
import megamedical.utils as utils

# %%
# processing bulwark. datasets can either be a string, or a list
# of datasets. If datasets is a list, then you can't visualize.
# if slurm == true, then no visualization is allowed.
#for plane in self.dset_info[dset_name]["planes"]:
#     put.display_processing_slices(loaded_image, loaded_label, plane)
# BrainTumour  
#  Colon  Heart  HepaticVessel  Hippocampus  Liver  Lung  Pancreas  Prostate  Spleen
pf.process_dataset(datasets=["MSD"],
                   subdsets=None,
                   version='4.0',
                   save_slices=True,
                   slurm=True,
                   visualize=False,
                   redo_processed=True,
                   subsets=["megamedical"])
# Out:
# Processing: Spleen:   0%|                                                                                                                                             | 0/41 [00:00<?, ?image/s]
# Processing: Spleen:   2%|███▏                                                                                                                                 | 1/41 [00:44<29:56, 44.91s/image]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [2], in <cell line: 8>()
#       1 # processing bulwark. datasets can either be a string, or a list
#       2 # of datasets. If datasets is a list, then you can't visualize.
#       3 # if slurm == true, then no visualization is allowed.
#    (...)
#       6 # BrainTumour
#       7 #  Colon  Heart  HepaticVessel  Hippocampus  Liver  Lung  Pancreas  Prostate  Spleen
# ----> 8 pf.process_dataset(datasets=["MSD"],
#       9                    subdsets=["Spleen"],
#      10                    version='4.0',
#      11                    save_slices=False,
#      12                    slurm=False,
#      13                    visualize=True,
#      14                    redo_processed=True,
#      15                    subsets=["megamedical"])
#
# File ~/src/MegaMedical/megamedical/src/proc_funcs.py:195, in process_dataset(datasets, subdsets, version, save_slices, slurm, timeout, visualize, show_hists, redo_processed, subsets)
#     193 for dset in dset_names:
#     194     if "megamedical" in subsets:
# --> 195         do.proc_func(dset,
#     196                     version,
#     197                     show_hists,
#     198                     visualize,
#     199                     save_slices,
#     200                     redo_processed)
#     201     elif "midslice" in subsets:
#     202         raise NotImplementedError("Not implemented yet")
#
# File ~/src/MegaMedical/megamedical/datasets/MSD/process_assets/process.py:155, in MSD.proc_func(self, dset_name, version, show_hists, show_imgs, save_slices, redo_processed)
#     152 loaded_label = nib.load(label_dir)
#     154 if len(loaded_image.shape) == 3:
# --> 155     loaded_image = put.resample_nib(loaded_image)
#     156     loaded_label = put.resample_mask_to(loaded_label, loaded_image)
#     158 loaded_image = loaded_image.get_fdata()
#
# File ~/src/MegaMedical/megamedical/utils/proc_utils.py:162, in resample_nib(img, voxel_spacing, order)
#     156 new_shp = tuple(np.rint([
#     157     shp[0] * zms[0] / voxel_spacing[0],
#     158     shp[1] * zms[1] / voxel_spacing[1],
#     159     shp[2] * zms[2] / voxel_spacing[2]
#     160     ]).astype(int))
#     161 new_aff = nib.affines.rescale_affine(aff, shp, voxel_spacing, new_shp)
# --> 162 new_img = nip.resample_from_to(img, (new_shp, new_aff), order=order, cval=-1024)
#     163 return new_img
#
# File ~/anaconda3/envs/UVS/lib/python3.9/site-packages/nibabel/processing.py:174, in resample_from_to(from_img, to_vox_map, order, mode, cval, out_class)
#     172 to_vox2from_vox = npl.inv(a_from_affine).dot(a_to_affine)
#     173 rzs, trans = to_matvec(to_vox2from_vox)
# --> 174 data = spnd.affine_transform(from_img.dataobj,
#     175                              rzs,
#     176                              trans,
#     177                              to_shape,
#     178                              order=order,
#     179                              mode=mode,
#     180                              cval=cval)
#     181 return out_class(data, to_affine, from_img.header)
#
# File ~/.local/lib/python3.9/site-packages/scipy/ndimage/_interpolation.py:611, in affine_transform(input, matrix, offset, output_shape, output, order, mode, cval, prefilter)
#     608     _nd_image.zoom_shift(filtered, matrix, offset/matrix, output, order,
#     609                          mode, cval, npad, False)
#     610 else:
# --> 611     _nd_image.geometric_transform(filtered, None, None, matrix, offset,
#     612                                   output, order, mode, cval, npad, None,
#     613                                   None)
#     614 return output
#
# KeyboardInterrupt:
