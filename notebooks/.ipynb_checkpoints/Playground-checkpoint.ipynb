# %%
import megamedical
import megamedical.src.proc_funcs as pf
import megamedical.utils as utils

# %%
# processing bulwark. datasets can either be a string, or a list
# of datasets. If datasets is a list, then you can't visualize.
# if slurm == true, then no visualization is allowed.
pf.process_dataset(datasets=["CHAOS"],
                   version='4.0',
                   save_slices=True,
                   slurm=False,
                   visualize=False,
                   redo_processed=True,
                   subsets=["megamedical"])
# Out:
# Processing: CT:   0%|                                                                                        | 0/20 [00:00<?, ?image/s]
# Processing: CT:   5%|████                                                                            | 1/20 [00:24<07:36, 24.02s/image]
# Processing: CT:  10%|████████                                                                        | 2/20 [00:58<08:46, 29.25s/image]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [2], in <cell line: 4>()
#       1 # processing bulwark. datasets can either be a string, or a list
#       2 # of datasets. If datasets is a list, then you can't visualize.
#       3 # if slurm == true, then no visualization is allowed.
# ----> 4 pf.process_dataset(datasets=["CHAOS"],
#       5                    version='4.0',
#       6                    save_slices=False,
#       7                    slurm=False,
#       8                    visualize=True,
#       9                    redo_processed=True,
#      10                    subsets=["megamedical"])
#
# File ~/src/MegaMedical/megamedical/src/proc_funcs.py:194, in process_dataset(datasets, version, save_slices, slurm, timeout, visualize, show_hists, redo_processed, subsets)
#     192 for dset in dset_names:
#     193     if "megamedical" in subsets:
# --> 194         do.proc_func(dset,
#     195                     version,
#     196                     show_hists,
#     197                     visualize,
#     198                     save_slices,
#     199                     redo_processed)
#     200     elif "midslice" in subsets:
#     201         raise NotImplementedError("Not implemented yet")
#
# File ~/src/MegaMedical/megamedical/datasets/CHAOS/process_assets/process.py:79, in CHAOS.proc_func(self, dset_name, version, show_hists, show_imgs, save_slices, redo_processed)
#      76         assert not (loaded_image is None), "Invalid Image"
#      77         assert not (loaded_label is None), "Invalid Label"
# ---> 79         pps.produce_slices(proc_dir,
#      80                           version,
#      81                           dset_name,
#      82                           image,
#      83                           loaded_image,
#      84                           loaded_label,
#      85                           self.dset_info[dset_name],
#      86                           show_hists=show_hists,
#      87                           show_imgs=show_imgs,
#      88                           save_slices=save_slices)
#      89 except Exception as e:
#      90     print(e)
#
# File ~/src/MegaMedical/megamedical/src/preprocess_scripts.py:91, in produce_slices(root_dir, version, dataset, subject_name, loaded_image, loaded_label, dset_info, resolutions, save_slices, show_hists, show_imgs)
#      88 bin_mask = np.float32((square_label==label))
#      90 #produce resized segmentations
# ---> 91 bin_seg_res = blur_and_resize(bin_mask, old_size, new_size=res, order=0)
#      93 #place resized segs in regular array
#      94 seg_res[..., lab_idx] = bin_seg_res
#
# File ~/src/MegaMedical/megamedical/utils/proc_utils.py:35, in blur_and_resize(image, old_size, new_size, order)
#      32 sigma = 1/4 * old_size / new_size
#      33 ratio = new_size/old_size
# ---> 35 blurred_resized_image = ndimage.gaussian_filter(image, sigma=sigma)
#      37 if len(blurred_resized_image.shape) == 2:
#      38     zoom_tup = (ratio, ratio)
#
# File ~/.local/lib/python3.9/site-packages/scipy/ndimage/_filters.py:342, in gaussian_filter(input, sigma, order, output, mode, cval, truncate)
#     340 if len(axes) > 0:
#     341     for axis, sigma, order, mode in axes:
# --> 342         gaussian_filter1d(input, sigma, axis, order, output,
#     343                           mode, cval, truncate)
#     344         input = output
#     345 else:
#
# File ~/.local/lib/python3.9/site-packages/scipy/ndimage/_filters.py:261, in gaussian_filter1d(input, sigma, axis, order, output, mode, cval, truncate)
#     259 # Since we are calling correlate, not convolve, revert the kernel
#     260 weights = _gaussian_kernel1d(sigma, order, lw)[::-1]
# --> 261 return correlate1d(input, weights, axis, output, mode, cval, 0)
#
# File ~/.local/lib/python3.9/site-packages/scipy/ndimage/_filters.py:133, in correlate1d(input, weights, axis, output, mode, cval, origin)
#     129     raise ValueError('Invalid origin; origin must satisfy '
#     130                      '-(len(weights) // 2) <= origin <= '
#     131                      '(len(weights)-1) // 2')
#     132 mode = _ni_support._extend_mode_to_code(mode)
# --> 133 _nd_image.correlate1d(input, weights, axis, output, mode, cval,
#     134                       origin)
#     135 return output
#
# KeyboardInterrupt:
